# %%
import numpy as np
import matplotlib.pyplot as plt

import environment
import parameters
# import pg_network
import other_agents
import RL_brain
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# /Users/11yunyi/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/11yunyi/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/11yunyi/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/11yunyi/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/11yunyi/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/11yunyi/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From /Users/11yunyi/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:61: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# /Users/11yunyi/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/11yunyi/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/11yunyi/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/11yunyi/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/11yunyi/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/11yunyi/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def discount(x, gamma):
    """
    Given vector x, computes a vector y such that
    y[i] = x[i] + gamma * x[i+1] + gamma^2 x[i+2] + ...
    """
    out = np.zeros(len(x))
    out[-1] = x[-1]
    for i in reversed(range(len(x)-1)):
        out[i] = x[i] + gamma*out[i+1]
    assert x.ndim >= 1
    # More efficient version:
    # scipy.signal.lfilter([1],[1,-gamma],x[::-1], axis=0)[::-1]
    return out


def categorical_sample(prob_n):
    """
    Sample from categorical distribution,
    specified by a vector of class probabilities
    """
    prob_n = np.asarray(prob_n)
    csprob_n = np.cumsum(prob_n)
    return (csprob_n > np.random.rand()).argmax()


def get_traj(test_type, pa, env, episode_max_length, pg_resume=None, render=False):
    """
    Run agent-environment loop for one whole episode (trajectory)
    Return dictionary of results
    """

    if test_type == 'PG':  # load trained parameters
        tf.reset_default_graph()
        # pg_learner = pg_network.PGLearner(pa)
        rl = RL_brain.PolicyGradient(n_actions=pa.network_output_dim,
                                     network_input_width=pa.network_input_width,
                                     network_input_height=pa.network_input_height,
                                     n_features=pa.network_input_width * pa.network_input_height,
                                     learning_rate=0.02)#初始化一个PG的agent
        rl.load_data(pg_resume)

        # net_handle = open(pg_resume, 'rb')
        # net_params = pickle.load(net_handle)
        # pg_learner.set_net_params(net_params)

    env.reset()
    rews = []

    ob = env.observe()#获得现在环境的观察值

    for _ in range(episode_max_length):#在当前观察值下选择动作

        if test_type == 'PG':
            a = rl.choose_action(ob)

        elif test_type == 'Tetris':
            a = other_agents.get_packer_action(env.machine, env.job_slot)

        elif test_type == 'SJF':
            a = other_agents.get_sjf_action(env.machine, env.job_slot)

        elif test_type == 'Random':
            a = other_agents.get_random_action(env.job_slot)
        
        elif test_type == 'packer':
            a = other_agents.get_packer_sjf_action(env.machine, env.job_slot,0.8)

        ob, rew, done, info = env.step(a, repeat=True)#执行一个动作，获得执行完这个动作之后的观测值

        rews.append(rew)##把所有的单步奖励添加到rews里

        if done: break#如果单个task结束，跳出循环
        if render: env.render()
        # env.render()

    return np.array(rews), info#返回这个episode的奖励轨迹和执行的job轨迹


def launch(pa, pg_resume=None, render=False, plot=False, repre='image', end='no_new_job'):

    # ---- Parameters ----

    test_types = ['Tetris', 'SJF','packer','Random']#测试的类型分为Tetris，SJF和packer

    if pg_resume is not None:
        test_types = ['PG'] + test_types
        print(test_types)
    env = environment.Env(pa, render, repre=repre, end=end)#初始化一个环境

    all_discount_rews = {}
    jobs_slow_down = {}
    work_complete = {}
    work_remain = {}
    job_len_remain = {}
    num_job_remain = {}
    job_remain_delay = {}

    for test_type in test_types:
        all_discount_rews[test_type] = []
        jobs_slow_down[test_type] = []
        work_complete[test_type] = []
        work_remain[test_type] = []
        job_len_remain[test_type] = []
        num_job_remain[test_type] = []
        job_remain_delay[test_type] = []

    for seq_idx in range(pa.num_ex):
        #一组有pa.num_ex数量的序列，每个序列代表一整个task（一整个task就是，比如要完成50个任务的安排）
        print('\n\n')
        print("=============== " + str(seq_idx) + " ===============")

        for test_type in test_types:

            rews, info = get_traj(test_type, pa, env, pa.episode_max_length, pg_resume)

            print("---------- " + test_type + " -----------")

            print("total discount reward : \t %s" % (discount(rews, pa.discount)[0]))

            all_discount_rews[test_type].append(
                discount(rews, pa.discount)[0]
            )

            # ------------------------
            # ---- per job stat ----
            # ------------------------

            enter_time = np.array([info.record[i].enter_time for i in range(len(info.record))])
            finish_time = np.array([info.record[i].finish_time for i in range(len(info.record))])
            job_len = np.array([info.record[i].len for i in range(len(info.record))])
            job_total_size = np.array([np.sum(info.record[i].res_vec) for i in range(len(info.record))])
            #print('finish_time',finish_time)
            finished_idx = (finish_time >= 0)
            #print('finish_idx',finished_idx)
            unfinished_idx = (finish_time < 0)

            jobs_slow_down[test_type].append(
                (finish_time[finished_idx] - enter_time[finished_idx])
            )
            work_complete[test_type].append(
                np.sum(job_len[finished_idx] * job_total_size[finished_idx])
            )
            work_remain[test_type].append(
                np.sum(job_len[unfinished_idx] * job_total_size[unfinished_idx])
            )
            job_len_remain[test_type].append(
                np.sum(job_len[unfinished_idx])
            )
            num_job_remain[test_type].append(
                len(job_len[unfinished_idx])
            )
            job_remain_delay[test_type].append(
                np.sum(pa.episode_max_length - enter_time[unfinished_idx])
            )

        env.seq_no = (env.seq_no + 1) % env.pa.num_ex

    # -- matplotlib colormap no overlap --
    if plot:
        num_colors = len(test_types)
        cm = plt.get_cmap('gist_rainbow')
        fig = plt.figure()
        ax = fig.add_subplot(111)
        ax.set_prop_cycle(color=['grey', 'purple', 'blue', 'green', 'orange', 'red'])
        #ax.set_color_cycle([cm(1. * i / num_colors) for i in range(num_colors)])

        for test_type in test_types:
            slow_down_cdf = np.sort(np.concatenate(jobs_slow_down[test_type]))
            slow_down_yvals = np.arange(len(slow_down_cdf))/float(len(slow_down_cdf))
            ax.plot(slow_down_cdf, slow_down_yvals, linewidth=2, label=test_type)

        plt.legend(loc=4)
        plt.xlabel("Completion time", fontsize=20)
        plt.ylabel("CDF", fontsize=20)
        plt.show()
        #plt.savefig(pg_resume + "_slowdown_fig" + ".pdf")

    return all_discount_rews, jobs_slow_down


def main():
    pa = parameters.Parameters()

    pa.simu_len = 120# 5000  # 1000
    pa.num_ex = 100  # 100
    pa.num_nw = pa.simu_len
    pa.num_seq_per_batch = 20
    # pa.max_nw_size = 5
    # pa.job_len = 5
    pa.new_job_rate = 1
    pa.discount = 1

    pa.episode_max_length = 20000  # 2000

    pa.compute_dependent_parameters()

    render = True

    plot = True  # plot slowdown cdf

    pg_resume = None
    #pg_resume = 'data/pg_re_discount_1_rate_0.3_simu_len_200_num_seq_per_batch_20_ex_10_nw_10_1450.pkl'
    #pg_resume = 'data/pg_re_1000_discount_1_5990.pkl'
    #pg_resume='data/tem_10.ckpt'
    pa.unseen = True

    all_discount_rews, jobs_slow_down=launch(pa, pg_resume, render, plot, repre='image', end='all_done')
    for k in all_discount_rews:
        print(np.average(np.concatenate(jobs_slow_down[k])))



if __name__ == '__main__':
    main()
# Out:
# Load on # 0 resource dimension is 2.667116666666667
# Load on # 1 resource dimension is 3.08825
#
#
#
# =============== 0 ===============
# ---------- Tetris -----------
# total discount reward : 	 -13629.0
# ---------- SJF -----------
# total discount reward : 	 -5709.0
# ---------- packer -----------
# total discount reward : 	 -11869.0
# ---------- Random -----------
# total discount reward : 	 -14159.0
#
#
#
# =============== 1 ===============
# ---------- Tetris -----------
# total discount reward : 	 -16200.0
# ---------- SJF -----------
# total discount reward : 	 -6138.0
# ---------- packer -----------
# total discount reward : 	 -14589.0
# ---------- Random -----------
# total discount reward : 	 -13733.0
#
#
#
# =============== 2 ===============
# ---------- Tetris -----------
# total discount reward : 	 -21269.0
# ---------- SJF -----------
# total discount reward : 	 -6473.0
# ---------- packer -----------
# total discount reward : 	 -20049.0
# ---------- Random -----------
# total discount reward : 	 -15678.0
#
#
#
# =============== 3 ===============
# ---------- Tetris -----------
# total discount reward : 	 -17848.0
# ---------- SJF -----------
# total discount reward : 	 -8277.0
# ---------- packer -----------
# total discount reward : 	 -16559.0
# ---------- Random -----------
# total discount reward : 	 -15936.0
#
#
#
# =============== 4 ===============
# ---------- Tetris -----------
# total discount reward : 	 -20868.0
# ---------- SJF -----------
# total discount reward : 	 -8788.0
# ---------- packer -----------
# total discount reward : 	 -19738.0
# ---------- Random -----------
# total discount reward : 	 -16649.0
#
#
#
# =============== 5 ===============
# ---------- Tetris -----------
# total discount reward : 	 -18417.0
# ---------- SJF -----------
# total discount reward : 	 -7396.0
# ---------- packer -----------
# total discount reward : 	 -18336.0
# ---------- Random -----------
# total discount reward : 	 -17147.0
#
#
#
# =============== 6 ===============
# ---------- Tetris -----------
# total discount reward : 	 -14825.0
# ---------- SJF -----------
# total discount reward : 	 -5561.0
# ---------- packer -----------
# total discount reward : 	 -13527.0
# ---------- Random -----------
# total discount reward : 	 -14052.0
#
#
#
# =============== 7 ===============
# ---------- Tetris -----------
# total discount reward : 	 -17775.0
# ---------- SJF -----------
# total discount reward : 	 -7001.0
# ---------- packer -----------
# total discount reward : 	 -16429.0
# ---------- Random -----------
# total discount reward : 	 -16627.0
#
#
#
# =============== 8 ===============
# ---------- Tetris -----------
# total discount reward : 	 -18114.0
# ---------- SJF -----------
# total discount reward : 	 -6962.0
# ---------- packer -----------
# total discount reward : 	 -16906.0
# ---------- Random -----------
# total discount reward : 	 -15028.0
#
#
#
# =============== 9 ===============
# ---------- Tetris -----------
# total discount reward : 	 -15823.0
# ---------- SJF -----------
# total discount reward : 	 -5612.0
# ---------- packer -----------
# total discount reward : 	 -15070.0
# ---------- Random -----------
# total discount reward : 	 -14819.0
#
#
#
# =============== 10 ===============
# ---------- Tetris -----------
# total discount reward : 	 -13183.0
# ---------- SJF -----------
# total discount reward : 	 -6959.0
# ---------- packer -----------
# total discount reward : 	 -12352.0
# ---------- Random -----------
# total discount reward : 	 -15427.0
#
#
#
# =============== 11 ===============
# ---------- Tetris -----------
# total discount reward : 	 -18960.0
# ---------- SJF -----------
# total discount reward : 	 -6608.0
# ---------- packer -----------
# total discount reward : 	 -17496.0
# ---------- Random -----------
# total discount reward : 	 -14958.0
#
#
#
# =============== 12 ===============
# ---------- Tetris -----------
# total discount reward : 	 -19126.0
# ---------- SJF -----------
# total discount reward : 	 -6304.0
# ---------- packer -----------
# total discount reward : 	 -17649.0
# ---------- Random -----------
# total discount reward : 	 -16121.0
#
#
#
# =============== 13 ===============
# ---------- Tetris -----------
# total discount reward : 	 -15863.0
# ---------- SJF -----------
# total discount reward : 	 -4744.0
# ---------- packer -----------
# total discount reward : 	 -14466.0
# ---------- Random -----------
# total discount reward : 	 -14203.0
#
#
#
# =============== 14 ===============
# ---------- Tetris -----------
# total discount reward : 	 -12981.0
# ---------- SJF -----------
# total discount reward : 	 -5352.0
# ---------- packer -----------
# total discount reward : 	 -11255.0
# ---------- Random -----------
# total discount reward : 	 -13512.0
#
#
#
# =============== 15 ===============
# ---------- Tetris -----------
# total discount reward : 	 -17569.0
# ---------- SJF -----------
# total discount reward : 	 -6940.0
# ---------- packer -----------
# total discount reward : 	 -16921.0
# ---------- Random -----------
# total discount reward : 	 -15524.0
#
#
#
# =============== 16 ===============
# ---------- Tetris -----------
# total discount reward : 	 -14796.0
# ---------- SJF -----------
# total discount reward : 	 -6804.0
# ---------- packer -----------
# total discount reward : 	 -12928.0
# ---------- Random -----------
# total discount reward : 	 -15358.0
#
#
#
# =============== 17 ===============
# ---------- Tetris -----------
# total discount reward : 	 -18711.0
# ---------- SJF -----------
# total discount reward : 	 -6927.0
# ---------- packer -----------
# total discount reward : 	 -17351.0
# ---------- Random -----------
# total discount reward : 	 -17625.0
#
#
#
# =============== 18 ===============
# ---------- Tetris -----------
# total discount reward : 	 -15319.0
# ---------- SJF -----------
# total discount reward : 	 -6786.0
# ---------- packer -----------
# total discount reward : 	 -14444.0
# ---------- Random -----------
# total discount reward : 	 -14335.0
#
#
#
# =============== 19 ===============
# ---------- Tetris -----------
# total discount reward : 	 -14487.0
# ---------- SJF -----------
# total discount reward : 	 -4251.0
# ---------- packer -----------
# total discount reward : 	 -13658.0
# ---------- Random -----------
# total discount reward : 	 -15858.0
#
#
#
# =============== 20 ===============
# ---------- Tetris -----------
# total discount reward : 	 -18123.0
# ---------- SJF -----------
# total discount reward : 	 -6587.0
# ---------- packer -----------
# total discount reward : 	 -17283.0
# ---------- Random -----------
# total discount reward : 	 -15590.0
#
#
#
# =============== 21 ===============
# ---------- Tetris -----------
# total discount reward : 	 -11660.0
# ---------- SJF -----------
# total discount reward : 	 -5327.0
# ---------- packer -----------
# total discount reward : 	 -10614.0
# ---------- Random -----------
# total discount reward : 	 -13085.0
#
#
#
# =============== 22 ===============
# ---------- Tetris -----------
# total discount reward : 	 -14275.0
# ---------- SJF -----------
# total discount reward : 	 -6733.0
# ---------- packer -----------
# total discount reward : 	 -11553.0
# ---------- Random -----------
# total discount reward : 	 -14433.0
#
#
#
# =============== 23 ===============
# ---------- Tetris -----------
# total discount reward : 	 -21877.0
# ---------- SJF -----------
# total discount reward : 	 -7245.0
# ---------- packer -----------
# total discount reward : 	 -20795.0
# ---------- Random -----------
# total discount reward : 	 -13930.0
#
#
#
# =============== 24 ===============
# ---------- Tetris -----------
# total discount reward : 	 -21778.0
# ---------- SJF -----------
# total discount reward : 	 -7595.0
# ---------- packer -----------
# total discount reward : 	 -20764.0
# ---------- Random -----------
# total discount reward : 	 -17584.0
#
#
#
# =============== 25 ===============
# ---------- Tetris -----------
# total discount reward : 	 -12851.0
# ---------- SJF -----------
# total discount reward : 	 -6010.0
# ---------- packer -----------
# total discount reward : 	 -12132.0
# ---------- Random -----------
# total discount reward : 	 -16635.0
#
#
#
# =============== 26 ===============
# ---------- Tetris -----------
# total discount reward : 	 -19253.0
# ---------- SJF -----------
# total discount reward : 	 -7564.0
# ---------- packer -----------
# total discount reward : 	 -17757.0
# ---------- Random -----------
# total discount reward : 	 -16549.0
#
#
#
# =============== 27 ===============
# ---------- Tetris -----------
# total discount reward : 	 -17134.0
# ---------- SJF -----------
# total discount reward : 	 -5499.0
# ---------- packer -----------
# total discount reward : 	 -16484.0
# ---------- Random -----------
# total discount reward : 	 -15327.0
#
#
#
# =============== 28 ===============
# ---------- Tetris -----------
# total discount reward : 	 -21158.0
# ---------- SJF -----------
# total discount reward : 	 -6981.0
# ---------- packer -----------
# total discount reward : 	 -19699.0
# ---------- Random -----------
# total discount reward : 	 -17837.0
#
#
#
# =============== 29 ===============
# ---------- Tetris -----------
# total discount reward : 	 -16202.0
# ---------- SJF -----------
# total discount reward : 	 -7528.0
# ---------- packer -----------
# total discount reward : 	 -15715.0
# ---------- Random -----------
# total discount reward : 	 -16638.0
#
#
#
# =============== 30 ===============
# ---------- Tetris -----------
# total discount reward : 	 -16997.0
# ---------- SJF -----------
# total discount reward : 	 -5331.0
# ---------- packer -----------
# total discount reward : 	 -15731.0
# ---------- Random -----------
# total discount reward : 	 -15779.0
#
#
#
# =============== 31 ===============
# ---------- Tetris -----------
# total discount reward : 	 -17268.0
# ---------- SJF -----------
# total discount reward : 	 -6687.0
# ---------- packer -----------
# total discount reward : 	 -16407.0
# ---------- Random -----------
# total discount reward : 	 -17479.0
#
#
#
# =============== 32 ===============
# ---------- Tetris -----------
# total discount reward : 	 -18172.0
# ---------- SJF -----------
# total discount reward : 	 -6604.0
# ---------- packer -----------
# total discount reward : 	 -16590.0
# ---------- Random -----------
# total discount reward : 	 -16192.0
#
#
#
# =============== 33 ===============
# ---------- Tetris -----------
# total discount reward : 	 -19090.0
# ---------- SJF -----------
# total discount reward : 	 -6000.0
# ---------- packer -----------
# total discount reward : 	 -17728.0
# ---------- Random -----------
# total discount reward : 	 -14481.0
#
#
#
# =============== 34 ===============
# ---------- Tetris -----------
# total discount reward : 	 -14064.0
# ---------- SJF -----------
# total discount reward : 	 -5006.0
# ---------- packer -----------
# total discount reward : 	 -12863.0
# ---------- Random -----------
# total discount reward : 	 -13437.0
#
#
#
# =============== 35 ===============
# ---------- Tetris -----------
# total discount reward : 	 -15570.0
# ---------- SJF -----------
# total discount reward : 	 -7008.0
# ---------- packer -----------
# total discount reward : 	 -14405.0
# ---------- Random -----------
# total discount reward : 	 -15553.0
#
#
#
# =============== 36 ===============
# ---------- Tetris -----------
# total discount reward : 	 -19928.0
# ---------- SJF -----------
# total discount reward : 	 -8847.0
# ---------- packer -----------
# total discount reward : 	 -17768.0
# ---------- Random -----------
# total discount reward : 	 -16896.0
#
#
#
# =============== 37 ===============
# ---------- Tetris -----------
# total discount reward : 	 -11884.0
# ---------- SJF -----------
# total discount reward : 	 -7000.0
# ---------- packer -----------
# total discount reward : 	 -11156.0
# ---------- Random -----------
# total discount reward : 	 -15261.0
#
#
#
# =============== 38 ===============
# ---------- Tetris -----------
# total discount reward : 	 -14903.0
# ---------- SJF -----------
# total discount reward : 	 -5662.0
# ---------- packer -----------
# total discount reward : 	 -13858.0
# ---------- Random -----------
# total discount reward : 	 -16927.0
#
#
#
# =============== 39 ===============
# ---------- Tetris -----------
# total discount reward : 	 -13953.0
# ---------- SJF -----------
# total discount reward : 	 -5939.0
# ---------- packer -----------
# total discount reward : 	 -12833.0
# ---------- Random -----------
# total discount reward : 	 -15527.0
#
#
#
# =============== 40 ===============
# ---------- Tetris -----------
# total discount reward : 	 -13379.0
# ---------- SJF -----------
# total discount reward : 	 -7228.0
# ---------- packer -----------
# total discount reward : 	 -12051.0
# ---------- Random -----------
# total discount reward : 	 -16473.0
#
#
#
# =============== 41 ===============
# ---------- Tetris -----------
# total discount reward : 	 -17279.0
# ---------- SJF -----------
# total discount reward : 	 -8115.0
# ---------- packer -----------
# total discount reward : 	 -16505.0
# ---------- Random -----------
# total discount reward : 	 -18626.0
#
#
#
# =============== 42 ===============
# ---------- Tetris -----------
# total discount reward : 	 -18332.0
# ---------- SJF -----------
# total discount reward : 	 -7313.0
# ---------- packer -----------
# total discount reward : 	 -16961.0
# ---------- Random -----------
# total discount reward : 	 -16660.0
#
#
#
# =============== 43 ===============
# ---------- Tetris -----------
# total discount reward : 	 -20903.0
# ---------- SJF -----------
# total discount reward : 	 -6596.0
# ---------- packer -----------
# total discount reward : 	 -19990.0
# ---------- Random -----------
# total discount reward : 	 -15470.0
#
#
#
# =============== 44 ===============
# ---------- Tetris -----------
# total discount reward : 	 -15461.0
# ---------- SJF -----------
# total discount reward : 	 -5837.0
# ---------- packer -----------
# total discount reward : 	 -13621.0
# ---------- Random -----------
# total discount reward : 	 -16765.0
#
#
#
# =============== 45 ===============
# ---------- Tetris -----------
# total discount reward : 	 -23208.0
# ---------- SJF -----------
# total discount reward : 	 -9046.0
# ---------- packer -----------
# total discount reward : 	 -21823.0
# ---------- Random -----------
# total discount reward : 	 -18146.0
#
#
#
# =============== 46 ===============
# ---------- Tetris -----------
# total discount reward : 	 -17769.0
# ---------- SJF -----------
# total discount reward : 	 -6108.0
# ---------- packer -----------
# total discount reward : 	 -16712.0
# ---------- Random -----------
# total discount reward : 	 -15311.0
#
#
#
# =============== 47 ===============
# ---------- Tetris -----------
# total discount reward : 	 -15411.0
# ---------- SJF -----------
# total discount reward : 	 -5884.0
# ---------- packer -----------
# total discount reward : 	 -15133.0
# ---------- Random -----------
# total discount reward : 	 -15359.0
#
#
#
# =============== 48 ===============
# ---------- Tetris -----------
# total discount reward : 	 -22702.0
# ---------- SJF -----------
# total discount reward : 	 -9688.0
# ---------- packer -----------
# total discount reward : 	 -21319.0
# ---------- Random -----------
# total discount reward : 	 -20024.0
#
#
#
# =============== 49 ===============
# ---------- Tetris -----------
# total discount reward : 	 -16050.0
# ---------- SJF -----------
# total discount reward : 	 -6218.0
# ---------- packer -----------
# total discount reward : 	 -15276.0
# ---------- Random -----------
# total discount reward : 	 -15626.0
#
#
#
# =============== 50 ===============
# ---------- Tetris -----------
# total discount reward : 	 -17292.0
# ---------- SJF -----------
# total discount reward : 	 -8383.0
# ---------- packer -----------
# total discount reward : 	 -16127.0
# ---------- Random -----------
# total discount reward : 	 -14700.0
#
#
#
# =============== 51 ===============
# ---------- Tetris -----------
# total discount reward : 	 -18954.0
# ---------- SJF -----------
# total discount reward : 	 -7337.0
# ---------- packer -----------
# total discount reward : 	 -17602.0
# ---------- Random -----------
# total discount reward : 	 -17414.0
#
#
#
# =============== 52 ===============
# ---------- Tetris -----------
# total discount reward : 	 -21596.0
# ---------- SJF -----------
# total discount reward : 	 -8241.0
# ---------- packer -----------
# total discount reward : 	 -20219.0
# ---------- Random -----------
# total discount reward : 	 -17761.0
#
#
#
# =============== 53 ===============
# ---------- Tetris -----------
# total discount reward : 	 -15356.0
# ---------- SJF -----------
# total discount reward : 	 -6049.0
# ---------- packer -----------
# total discount reward : 	 -14125.0
# ---------- Random -----------
# total discount reward : 	 -13740.0
#
#
#
# =============== 54 ===============
# ---------- Tetris -----------
# total discount reward : 	 -22762.0
# ---------- SJF -----------
# total discount reward : 	 -7253.0
# ---------- packer -----------
# total discount reward : 	 -21017.0
# ---------- Random -----------
# total discount reward : 	 -16913.0
#
#
#
# =============== 55 ===============
# ---------- Tetris -----------
# total discount reward : 	 -14599.0
# ---------- SJF -----------
# total discount reward : 	 -5244.0
# ---------- packer -----------
# total discount reward : 	 -13795.0
# ---------- Random -----------
# total discount reward : 	 -14047.0
#
#
#
# =============== 56 ===============
# ---------- Tetris -----------
# total discount reward : 	 -19020.0
# ---------- SJF -----------
# total discount reward : 	 -6810.0
# ---------- packer -----------
# total discount reward : 	 -17608.0
# ---------- Random -----------
# total discount reward : 	 -16268.0
#
#
#
# =============== 57 ===============
# ---------- Tetris -----------
# total discount reward : 	 -18166.0
# ---------- SJF -----------
# total discount reward : 	 -7341.0
# ---------- packer -----------
# total discount reward : 	 -16458.0
# ---------- Random -----------
# total discount reward : 	 -16913.0
#
#
#
# =============== 58 ===============
# ---------- Tetris -----------
# total discount reward : 	 -15030.0
# ---------- SJF -----------
# total discount reward : 	 -5480.0
# ---------- packer -----------
# total discount reward : 	 -13655.0
# ---------- Random -----------
# total discount reward : 	 -14430.0
#
#
#
# =============== 59 ===============
# ---------- Tetris -----------
# total discount reward : 	 -17250.0
# ---------- SJF -----------
# total discount reward : 	 -7552.0
# ---------- packer -----------
# total discount reward : 	 -15957.0
# ---------- Random -----------
# total discount reward : 	 -15269.0
#
#
#
# =============== 60 ===============
# ---------- Tetris -----------
# total discount reward : 	 -18122.0
# ---------- SJF -----------
# total discount reward : 	 -5825.0
# ---------- packer -----------
# total discount reward : 	 -16540.0
# ---------- Random -----------
# total discount reward : 	 -16282.0
#
#
#
# =============== 61 ===============
# ---------- Tetris -----------
# total discount reward : 	 -15767.0
# ---------- SJF -----------
# total discount reward : 	 -5798.0
# ---------- packer -----------
# total discount reward : 	 -13384.0
# ---------- Random -----------
# total discount reward : 	 -16001.0
#
#
#
# =============== 62 ===============
# ---------- Tetris -----------
# total discount reward : 	 -16428.0
# ---------- SJF -----------
# total discount reward : 	 -6268.0
# ---------- packer -----------
# total discount reward : 	 -15174.0
# ---------- Random -----------
# total discount reward : 	 -17389.0
#
#
#
# =============== 63 ===============
# ---------- Tetris -----------
# total discount reward : 	 -17789.0
# ---------- SJF -----------
# total discount reward : 	 -6759.0
# ---------- packer -----------
# total discount reward : 	 -16796.0
# ---------- Random -----------
# total discount reward : 	 -16792.0
#
#
#
# =============== 64 ===============
# ---------- Tetris -----------
# total discount reward : 	 -24583.0
# ---------- SJF -----------
# total discount reward : 	 -8136.0
# ---------- packer -----------
# total discount reward : 	 -22592.0
# ---------- Random -----------
# total discount reward : 	 -16986.0
#
#
#
# =============== 65 ===============
# ---------- Tetris -----------
# total discount reward : 	 -16938.0
# ---------- SJF -----------
# total discount reward : 	 -7478.0
# ---------- packer -----------
# total discount reward : 	 -15615.0
# ---------- Random -----------
# total discount reward : 	 -16536.0
#
#
#
# =============== 66 ===============
# ---------- Tetris -----------
# total discount reward : 	 -18262.0
# ---------- SJF -----------
# total discount reward : 	 -6831.0
# ---------- packer -----------
# total discount reward : 	 -16576.0
# ---------- Random -----------
# total discount reward : 	 -16994.0
#
#
#
# =============== 67 ===============
# ---------- Tetris -----------
# total discount reward : 	 -17050.0
# ---------- SJF -----------
# total discount reward : 	 -5852.0
# ---------- packer -----------
# total discount reward : 	 -15525.0
# ---------- Random -----------
# total discount reward : 	 -15881.0
#
#
#
# =============== 68 ===============
# ---------- Tetris -----------
# total discount reward : 	 -18277.0
# ---------- SJF -----------
# total discount reward : 	 -6821.0
# ---------- packer -----------
# total discount reward : 	 -17118.0
# ---------- Random -----------
# total discount reward : 	 -15409.0
#
#
#
# =============== 69 ===============
# ---------- Tetris -----------
# total discount reward : 	 -16862.0
# ---------- SJF -----------
# total discount reward : 	 -5823.0
# ---------- packer -----------
# total discount reward : 	 -16138.0
# ---------- Random -----------
# total discount reward : 	 -14098.0
#
#
#
# =============== 70 ===============
# ---------- Tetris -----------
# total discount reward : 	 -16587.0
# ---------- SJF -----------
# total discount reward : 	 -6285.0
# ---------- packer -----------
# total discount reward : 	 -15150.0
# ---------- Random -----------
# total discount reward : 	 -18126.0
#
#
#
# =============== 71 ===============
# ---------- Tetris -----------
# total discount reward : 	 -13789.0
# ---------- SJF -----------
# total discount reward : 	 -5752.0
# ---------- packer -----------
# total discount reward : 	 -12776.0
# ---------- Random -----------
# total discount reward : 	 -16763.0
#
#
#
# =============== 72 ===============
# ---------- Tetris -----------
# total discount reward : 	 -19726.0
# ---------- SJF -----------
# total discount reward : 	 -6045.0
# ---------- packer -----------
# total discount reward : 	 -18785.0
# ---------- Random -----------
# total discount reward : 	 -15724.0
#
#
#
# =============== 73 ===============
# ---------- Tetris -----------
# total discount reward : 	 -23889.0
# ---------- SJF -----------
# total discount reward : 	 -7344.0
# ---------- packer -----------
# total discount reward : 	 -22532.0
# ---------- Random -----------
# total discount reward : 	 -18913.0
#
#
#
# =============== 74 ===============
# ---------- Tetris -----------
# total discount reward : 	 -14178.0
# ---------- SJF -----------
# total discount reward : 	 -6073.0
# ---------- packer -----------
# total discount reward : 	 -13275.0
# ---------- Random -----------
# total discount reward : 	 -15169.0
#
#
#
# =============== 75 ===============
# ---------- Tetris -----------
# total discount reward : 	 -14285.0
# ---------- SJF -----------
# total discount reward : 	 -6145.0
# ---------- packer -----------
# total discount reward : 	 -13172.0
# ---------- Random -----------
# total discount reward : 	 -15070.0
#
#
#
# =============== 76 ===============
# ---------- Tetris -----------
# total discount reward : 	 -15040.0
# ---------- SJF -----------
# total discount reward : 	 -6132.0
# ---------- packer -----------
# total discount reward : 	 -13528.0
# ---------- Random -----------
# total discount reward : 	 -16248.0
#
#
#
# =============== 77 ===============
# ---------- Tetris -----------
# total discount reward : 	 -11969.0
# ---------- SJF -----------
# total discount reward : 	 -5147.0
# ---------- packer -----------
# total discount reward : 	 -10309.0
# ---------- Random -----------
# total discount reward : 	 -15671.0
#
#
#
# =============== 78 ===============
# ---------- Tetris -----------
# total discount reward : 	 -18315.0
# ---------- SJF -----------
# total discount reward : 	 -6254.0
# ---------- packer -----------
# total discount reward : 	 -16933.0
# ---------- Random -----------
# total discount reward : 	 -16505.0
#
#
#
# =============== 79 ===============
# ---------- Tetris -----------
# total discount reward : 	 -17514.0
# ---------- SJF -----------
# total discount reward : 	 -4960.0
# ---------- packer -----------
# total discount reward : 	 -16462.0
# ---------- Random -----------
# total discount reward : 	 -17178.0
#
#
#
# =============== 80 ===============
# ---------- Tetris -----------
# total discount reward : 	 -10695.0
# ---------- SJF -----------
# total discount reward : 	 -6234.0
# ---------- packer -----------
# total discount reward : 	 -9149.0
# ---------- Random -----------
# total discount reward : 	 -14722.0
#
#
#
# =============== 81 ===============
# ---------- Tetris -----------
# total discount reward : 	 -15445.0
# ---------- SJF -----------
# total discount reward : 	 -5121.0
# ---------- packer -----------
# total discount reward : 	 -14457.0
# ---------- Random -----------
# total discount reward : 	 -15128.0
#
#
#
# =============== 82 ===============
# ---------- Tetris -----------
# total discount reward : 	 -18843.0
# ---------- SJF -----------
# total discount reward : 	 -9215.0
# ---------- packer -----------
# total discount reward : 	 -17688.0
# ---------- Random -----------
# total discount reward : 	 -17843.0
#
#
#
# =============== 83 ===============
# ---------- Tetris -----------
# total discount reward : 	 -14958.0
# ---------- SJF -----------
# total discount reward : 	 -5049.0
# ---------- packer -----------
# total discount reward : 	 -14303.0
# ---------- Random -----------
# total discount reward : 	 -15536.0
#
#
#
# =============== 84 ===============
# ---------- Tetris -----------
# total discount reward : 	 -15956.0
# ---------- SJF -----------
# total discount reward : 	 -6088.0
# ---------- packer -----------
# total discount reward : 	 -14677.0
# ---------- Random -----------
# total discount reward : 	 -16426.0
#
#
#
# =============== 85 ===============
# ---------- Tetris -----------
# total discount reward : 	 -15477.0
# ---------- SJF -----------
# total discount reward : 	 -6756.0
# ---------- packer -----------
# total discount reward : 	 -14785.0
# ---------- Random -----------
# total discount reward : 	 -14991.0
#
#
#
# =============== 86 ===============
# ---------- Tetris -----------
# total discount reward : 	 -17765.0
# ---------- SJF -----------
# total discount reward : 	 -7467.0
# ---------- packer -----------
# total discount reward : 	 -16659.0
# ---------- Random -----------
# total discount reward : 	 -16956.0
#
#
#
# =============== 87 ===============
# ---------- Tetris -----------
# total discount reward : 	 -19510.0
# ---------- SJF -----------
# total discount reward : 	 -6698.0
# ---------- packer -----------
# total discount reward : 	 -18306.0
# ---------- Random -----------
# total discount reward : 	 -15011.0
#
#
#
# =============== 88 ===============
# ---------- Tetris -----------
# total discount reward : 	 -14739.0
# ---------- SJF -----------
# total discount reward : 	 -6173.0
# ---------- packer -----------
# total discount reward : 	 -13019.0
# ---------- Random -----------
# total discount reward : 	 -14880.0
#
#
#
# =============== 89 ===============
# ---------- Tetris -----------
# total discount reward : 	 -14887.0
# ---------- SJF -----------
# total discount reward : 	 -6076.0
# ---------- packer -----------
# total discount reward : 	 -13813.0
# ---------- Random -----------
# total discount reward : 	 -14639.0
#
#
#
# =============== 90 ===============
# ---------- Tetris -----------
# total discount reward : 	 -12724.0
# ---------- SJF -----------
# total discount reward : 	 -4527.0
# ---------- packer -----------
# total discount reward : 	 -12040.0
# ---------- Random -----------
# total discount reward : 	 -13583.0
#
#
#
# =============== 91 ===============
# ---------- Tetris -----------
# total discount reward : 	 -17544.0
# ---------- SJF -----------
# total discount reward : 	 -6488.0
# ---------- packer -----------
# total discount reward : 	 -15044.0
# ---------- Random -----------
# total discount reward : 	 -16127.0
#
#
#
# =============== 92 ===============
# ---------- Tetris -----------
# total discount reward : 	 -16434.0
# ---------- SJF -----------
# total discount reward : 	 -7152.0
# ---------- packer -----------
# total discount reward : 	 -14696.0
# ---------- Random -----------
# total discount reward : 	 -16379.0
#
#
#
# =============== 93 ===============
# ---------- Tetris -----------
# total discount reward : 	 -13926.0
# ---------- SJF -----------
# total discount reward : 	 -5194.0
# ---------- packer -----------
# total discount reward : 	 -13208.0
# ---------- Random -----------
# total discount reward : 	 -13921.0
#
#
#
# =============== 94 ===============
# ---------- Tetris -----------
# total discount reward : 	 -19911.0
# ---------- SJF -----------
# total discount reward : 	 -8983.0
# ---------- packer -----------
# total discount reward : 	 -18705.0
# ---------- Random -----------
# total discount reward : 	 -16843.0
#
#
#
# =============== 95 ===============
# ---------- Tetris -----------
# total discount reward : 	 -14050.0
# ---------- SJF -----------
# total discount reward : 	 -7004.0
# ---------- packer -----------
# total discount reward : 	 -12716.0
# ---------- Random -----------
# total discount reward : 	 -14966.0
#
#
#
# =============== 96 ===============
# ---------- Tetris -----------
# total discount reward : 	 -18140.0
# ---------- SJF -----------
# total discount reward : 	 -7234.0
# ---------- packer -----------
# total discount reward : 	 -17094.0
# ---------- Random -----------
# total discount reward : 	 -17065.0
#
#
#
# =============== 97 ===============
# ---------- Tetris -----------
# total discount reward : 	 -18652.0
# ---------- SJF -----------
# total discount reward : 	 -9234.0
# ---------- packer -----------
# total discount reward : 	 -17408.0
# ---------- Random -----------
# total discount reward : 	 -18990.0
#
#
#
# =============== 98 ===============
# ---------- Tetris -----------
# total discount reward : 	 -13443.0
# ---------- SJF -----------
# total discount reward : 	 -6776.0
# ---------- packer -----------
# total discount reward : 	 -12757.0
# ---------- Random -----------
# total discount reward : 	 -15244.0
#
#
#
# =============== 99 ===============
# ---------- Tetris -----------
# total discount reward : 	 -17209.0
# ---------- SJF -----------
# total discount reward : 	 -6737.0
# ---------- packer -----------
# total discount reward : 	 -15913.0
# ---------- Random -----------
# total discount reward : 	 -18339.0
# 201.92091666666667
# 115.53466666666667
# 191.58808333333334
# 193.22633333333334
